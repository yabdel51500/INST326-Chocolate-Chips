# %%
import pandas as pd
from pyecharts.charts import Map,Geo
from pyecharts import options as opts
from pyecharts.globals import ThemeType
from argparse import ArgumentParser

df1 = pd.read_csv('covid.csv')
df1['date'] = pd.to_datetime(df1['date'])
df2 = df1.sort_values(by = ['date'], ascending = False)
df3 = df2[df2['date'] == '2021-10-25']
df3.reset_index(drop = True, inplace = True)
df4 = df2[df2['date'] <= '2021-11-05']
df4.reset_index(drop = True, inplace = True)

country = list(df3['location'])
totalvax=list(df3['new_vaccinations_smoothed_per_million'])

list1 = [[country[i],totalvax[i]] for i in range(len(country))] 
map1 = Map(init_opts=opts.InitOpts(width='1000px', height='460px')) #create the map and set the size of the map
map1.add('Total Confirmed Vaccinations', list1, maptype='world')
map1.set_series_opts(label_opts=opts.LabelOpts(is_show = False)) 

map1.set_global_opts(visualmap_opts=opts.VisualMapOpts(max_=100 , is_piecewise = True, pieces=[
{'min': 9000, 'max': 9999},
{'min': 7000, 'max': 8999},
{'min': 5000, 'max': 6999},
{'min': 3000, 'max': 4999},
{'min': 1, 'max': 2999},
{'max': 0},]),
title_opts=opts.TitleOpts(title= "Covid-19 Worldwide Total Vaccinations INST326 Final", subtitle= 'Till November 5th, 2021', pos_left= 'center', padding=0, item_gap=2,
title_textstyle_opts= opts.TextStyleOpts(color='blue', font_weight= 'bold', font_family= 'Courier New', font_size=30), 
subtitle_textstyle_opts= opts.TextStyleOpts(color='black', font_weight='bold', font_family='Courier New', font_size=20)), 
legend_opts=opts.LegendOpts(is_show=False))

map1.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'world':'https://assets.pyecharts.org/assets/maps/world'
#         }
#     });
# </script>
#
#         <div id="8d105bad44844a6791dadfae00f12375" style="width:1000px; height:460px;"></div>
#
# <script>
#         require(['echarts', 'world'], function(echarts) {
#                 var chart_8d105bad44844a6791dadfae00f12375 = echarts.init(
#                     document.getElementById('8d105bad44844a6791dadfae00f12375'), 'white', {renderer: 'canvas'});
#                 var option_8d105bad44844a6791dadfae00f12375 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "name": "Total Confirmed Vaccinations",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "world",
#             "data": [
#                 {
#                     "name": "Asia",
#                     "value": 3908.0
#                 },
#                 {
#                     "name": "Cambodia",
#                     "value": 5100.0
#                 },
#                 {
#                     "name": "Chad",
#                     "value": 182.0
#                 },
#                 {
#                     "name": "Vatican",
#                     "value": null
#                 },
#                 {
#                     "name": "Malawi",
#                     "value": 310.0
#                 },
#                 {
#                     "name": "Germany",
#                     "value": 1548.0
#                 },
#                 {
#                     "name": "Montenegro",
#                     "value": 2285.0
#                 },
#                 {
#                     "name": "New Zealand",
#                     "value": 6849.0
#                 },
#                 {
#                     "name": "Kuwait",
#                     "value": null
#                 },
#                 {
#                     "name": "Gambia",
#                     "value": 1032.0
#                 },
#                 {
#                     "name": "United Arab Emirates",
#                     "value": 2801.0
#                 },
#                 {
#                     "name": "Greece",
#                     "value": 2211.0
#                 },
#                 {
#                     "name": "Macao",
#                     "value": 8387.0
#                 },
#                 {
#                     "name": "Serbia",
#                     "value": 5541.0
#                 },
#                 {
#                     "name": "Palau",
#                     "value": null
#                 },
#                 {
#                     "name": "Guyana",
#                     "value": 1978.0
#                 },
#                 {
#                     "name": "Bhutan",
#                     "value": 1317.0
#                 },
#                 {
#                     "name": "Eswatini",
#                     "value": 322.0
#                 },
#                 {
#                     "name": "France",
#                     "value": 1987.0
#                 },
#                 {
#                     "name": "Nicaragua",
#                     "value": 3549.0
#                 },
#                 {
#                     "name": "Turkey",
#                     "value": 2138.0
#                 },
#                 {
#                     "name": "Madagascar",
#                     "value": null
#                 },
#                 {
#                     "name": "Isle of Man",
#                     "value": 1065.0
#                 },
#                 {
#                     "name": "Togo",
#                     "value": 744.0
#                 },
#                 {
#                     "name": "Andorra",
#                     "value": 853.0
#                 },
#                 {
#                     "name": "Kosovo",
#                     "value": 2828.0
#                 },
#                 {
#                     "name": "South Africa",
#                     "value": 2673.0
#                 },
#                 {
#                     "name": "Marshall Islands",
#                     "value": null
#                 },
#                 {
#                     "name": "Portugal",
#                     "value": 605.0
#                 },
#                 {
#                     "name": "Guinea",
#                     "value": 1446.0
#                 },
#                 {
#                     "name": "Paraguay",
#                     "value": 3753.0
#                 },
#                 {
#                     "name": "Comoros",
#                     "value": 3755.0
#                 },
#                 {
#                     "name": "Israel",
#                     "value": 1333.0
#                 },
#                 {
#                     "name": "Guinea-Bissau",
#                     "value": 572.0
#                 },
#                 {
#                     "name": "Bolivia",
#                     "value": 2716.0
#                 },
#                 {
#                     "name": "Monaco",
#                     "value": null
#                 },
#                 {
#                     "name": "Netherlands",
#                     "value": 712.0
#                 },
#                 {
#                     "name": "Thailand",
#                     "value": 9860.0
#                 },
#                 {
#                     "name": "Cook Islands",
#                     "value": 2276.0
#                 },
#                 {
#                     "name": "Malta",
#                     "value": 3711.0
#                 },
#                 {
#                     "name": "Saint Vincent and the Grenadines",
#                     "value": 2669.0
#                 },
#                 {
#                     "name": "Russia",
#                     "value": 3375.0
#                 },
#                 {
#                     "name": "Czechia",
#                     "value": 1943.0
#                 },
#                 {
#                     "name": "Japan",
#                     "value": 5670.0
#                 },
#                 {
#                     "name": "Chile",
#                     "value": 9126.0
#                 },
#                 {
#                     "name": "Bahrain",
#                     "value": 2882.0
#                 },
#                 {
#                     "name": "Slovakia",
#                     "value": 591.0
#                 },
#                 {
#                     "name": "Gabon",
#                     "value": 481.0
#                 },
#                 {
#                     "name": "Papua New Guinea",
#                     "value": 524.0
#                 },
#                 {
#                     "name": "Brazil",
#                     "value": 7807.0
#                 },
#                 {
#                     "name": "Austria",
#                     "value": 2394.0
#                 },
#                 {
#                     "name": "Guatemala",
#                     "value": 2062.0
#                 },
#                 {
#                     "name": "Qatar",
#                     "value": 1063.0
#                 },
#                 {
#                     "name": "Jordan",
#                     "value": 1784.0
#                 },
#                 {
#                     "name": "Sierra Leone",
#                     "value": 1602.0
#                 },
#                 {
#                     "name": "Solomon Islands",
#                     "value": 1192.0
#                 },
#                 {

# %%
print("hello hi{u/200c}")
# Out:
# hello hi{u/200c}
